# %%
import os
if __name__ == '__main__':
  print("Welcome to Robospeaker 1.1 Created by Uttam")
  while True:
    x = input("enter ehat you want me to speak")
    if x=="q":
      os.system("say 'bye bye friend'")
      break
    command = f"say {x}"
    os.system(command)
# Out:
# Welcome to Robospeaker 1.1 Created by Uttam
# enter ehat you want me to speakuttam
# enter ehat you want me to speakbye
# enter ehat you want me to speakq
