# %%
print("hello uttam")
print("hello world")
# Out:
# hello uttam
# hello world

# %%
#variable in python
a = 4
print(a)
b = 55
print(b)
a=6.2
print(a)
c= True # False --> these are boolean variable
print(c)

d = "uttam"
print(d)
e = None
print(e)
# Out:
# 4
# 55
# 6.2
# True
# uttam
# None

# %%
num1 = 10
num2 = 2

# arithmatic operator
print("num1 + num2 is ", num1 + num2)
print("num1 - num2 is ", num1 - num2)
print("num1 * num2 is ", num1 * num2)
print("num1 / num2 is ", num1 / num2)
print("num1 // num2 is ", num1 // num2)
print("num1 ** num2 is ", num1 ** num2)
print("num1 % num2 is ", num1 % num2)

# Assignment operator
a = 4
a/=2
print(a)
# Out:
# num1 + num2 is  12
# num1 - num2 is  8
# num1 * num2 is  20
# num1 / num2 is  5.0
# num1 // num2 is  5
# num1 ** num2 is  100
# num1 % num2 is  0
# 2.0

# %%
#Comparison operator
x = 8
y=6
z = 6
print(x>y)
print(x<y)
print(x!=y)
# Out:
# True
# False
# True

# %%
#logical operator
print(x==z and x<y)
print(x==z or x<y)
print(not(False))
print(not(True))
# Out:
# False
# False
# True
# False
