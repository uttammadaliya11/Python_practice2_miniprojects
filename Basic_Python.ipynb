# %%
a=[1,5,3,7,4,"rangani","red"]
a.append("kanani")
a
# Out:
# [1, 5, 3, 7, 4, 'rangani', 'red', 'kanani']

# %%
len(a)
# Out:
# 8

# %%
a[2:]
# Out:
# [3, 7, 4, 'rangani', 'red', 'kanani']

# %%
a.reverse()
a
# Out:
# ['kanani', 'red', 'rangani', 4, 7, 3, 5, 1]

# %%
a.pop(-1)
a
# Out:
# ['kanani', 'red', 'rangani', 4, 7, 3, 5]

# %%
a.pop(-1)
a
# Out:
# [1, 5, 3, 7, 4, 'rangani', 'red']

# %%
my_disk={"one":1,"two":2,"three":3}
my_disk["four"]=4
my_disk
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4}

# %%
# my_disk.pop("one")
# my_disk

# %%
my_disk.values()
# Out:
# dict_values([1, 2, 3, 4])

# %%
my_disk.keys()
# my_disk.get("three")
# Out:
# dict_keys(['one', 'two', 'three', 'four'])
