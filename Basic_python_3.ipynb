# %%
name = "uttam123madaliya"
# for i in range(len(name)):
#   print(name[i])
print(name.center(30,"."))
print(len(name))
name.count("a")
print(name.isalnum())
# Out:
# .......uttam123madaliya.......
# 16
# True

# %%
a=int(input("enter your age="))
if a>18:
  print("you can drive")
else:
  print("you can't drive")
# Out:
# enter your age=45
# you can drive

# %%
a=int(input("enter your age="))
b=str(input("you have licence"))
if a>18 and b=="yes":
    print("you can drive")
else:
  print("you can't drive")
# Out:
# enter your age=19
# you have licenceyes
# you can drive

# %%
a=int(input("enter your age="))
b=str(input("you have licence"))
if a>18:
elif b=="yes":
  print("you can drive")
else:
  print("you can't drive")
# Out:
#   File "<tokenize>", line 6
#     break()
#     ^
# IndentationError: unindent does not match any outer indentation level
